# %%
from functions import factorial

# %%
from functions import eda

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Local environment with VS Code

left_raw = pd.read_csv("/Users/rohit/Documents/Rohit - Master's Applied Analytics/Term 2 Courses/Python for Data Analysis/Group Project/Datasets/left_dataset.csv")
right_raw = pd.read_csv("/Users/rohit/Documents/Rohit - Master's Applied Analytics/Term 2 Courses/Python for Data Analysis/Group Project/Datasets/right_dataset.csv")

eda(left_raw, right_raw)

# %%
# !pip install ssj
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install py_stringsimjoin
# !pip install py_stringmatching
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import py_stringsimjoin as ssj
import py_stringmatching as sm
import pandas as pd
import os, sys
from py_stringsimjoin.join.jaccard_join import jaccard_join
import ssj
from fuzzywuzzy import process 
import re

# %%
from functions import matched_algo

# %%
matched_algo(left_raw, right_raw)
# Out:
# Number of records in A: 94585
# Number of records in B: 91791
# /Users/rohit/opt/anaconda3/lib/python3.9/site-packages/py_stringsimjoin/utils/generic_helper.py:76: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   projected_dataframe = dataframe[proj_attrs].dropna(0,
# /Users/rohit/opt/anaconda3/lib/python3.9/site-packages/py_stringsimjoin/utils/generic_helper.py:76: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   projected_dataframe = dataframe[proj_attrs].dropna(0,
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# /Users/rohit/opt/anaconda3/lib/python3.9/site-packages/py_stringsimjoin/utils/generic_helper.py:76: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   projected_dataframe = dataframe[proj_attrs].dropna(0,
# ...
